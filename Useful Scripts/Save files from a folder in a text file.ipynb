# %%
### creates a list of paths of text files to save face locations 
import os
txt_list= [os.path.join('/home/saadi/Desktop/test_xml _write/images', file) for file in os.listdir('/home/saadi/Desktop/test_xml _write/images') if file.endswith('.jpg')]
print(txt_list)
txt_list.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))# reorganizes the list
print('###################################################')
print(txt_list)
# Out:
# ['/home/saadi/Desktop/test_xml _write/images/2735.jpg', '/home/saadi/Desktop/test_xml _write/images/4207.jpg', '/home/saadi/Desktop/test_xml _write/images/3168.jpg', '/home/saadi/Desktop/test_xml _write/images/6622.jpg', '/home/saadi/Desktop/test_xml _write/images/1949.jpg', '/home/saadi/Desktop/test_xml _write/images/6808.jpg', '/home/saadi/Desktop/test_xml _write/images/6616.jpg', '/home/saadi/Desktop/test_xml _write/images/4350.jpg', '/home/saadi/Desktop/test_xml _write/images/3940.jpg', '/home/saadi/Desktop/test_xml _write/images/7239.jpg', '/home/saadi/Desktop/test_xml _write/images/3040.jpg', '/home/saadi/Desktop/test_xml _write/images/3531.jpg', '/home/saadi/Desktop/test_xml _write/images/4441.jpg', '/home/saadi/Desktop/test_xml _write/images/850.jpg', '/home/saadi/Desktop/test_xml _write/images/2145.jpg', '/home/saadi/Desktop/test_xml _write/images/833.jpg', '/home/saadi/Desktop/test_xml _write/images/3942.jpg', '/home/saadi/Desktop/test_xml _write/images/69.jpg', '/home/saad
# ...

# %%
thefile = open('/home/saadi/darknet/attire_test.txt', 'w')
l = 0
for item in range(0,750):
      file_1 = txt_list[l]
      print(file_1)
      thefile.write("%s\n" % file_1)
      l = l+10
# Out:
# /home/saadi/Desktop/test_xml _write/images/0.jpg
# /home/saadi/Desktop/test_xml _write/images/10.jpg
# /home/saadi/Desktop/test_xml _write/images/20.jpg
# /home/saadi/Desktop/test_xml _write/images/30.jpg
# /home/saadi/Desktop/test_xml _write/images/40.jpg
# /home/saadi/Desktop/test_xml _write/images/50.jpg
# /home/saadi/Desktop/test_xml _write/images/60.jpg
# /home/saadi/Desktop/test_xml _write/images/70.jpg
# /home/saadi/Desktop/test_xml _write/images/80.jpg
# /home/saadi/Desktop/test_xml _write/images/90.jpg
# /home/saadi/Desktop/test_xml _write/images/100.jpg
# /home/saadi/Desktop/test_xml _write/images/110.jpg
# /home/saadi/Desktop/test_xml _write/images/120.jpg
# /home/saadi/Desktop/test_xml _write/images/130.jpg
# /home/saadi/Desktop/test_xml _write/images/140.jpg
# /home/saadi/Desktop/test_xml _write/images/150.jpg
# /home/saadi/Desktop/test_xml _write/images/160.jpg
# /home/saadi/Desktop/test_xml _write/images/170.jpg
# /home/saadi/Desktop/test_xml _write/images/180.jpg
# ...
