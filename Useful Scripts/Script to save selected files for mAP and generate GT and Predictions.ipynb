# %%
### creates a list of paths of text files to save face locations 
import os
txt_list= [os.path.join('/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted', file) for file in os.listdir('/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted') if file.endswith('.txt')]
print(txt_list)
txt_list.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))# reorganizes the list
print('###################################################')
print(txt_list)
# Out:
# ['/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/4976.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/2917.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/1643.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/4800.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/70.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/2250.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/701.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/5029.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/324.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/4154.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/461.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/7290.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/7070.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/846.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/7200.txt', '/home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /
# ...

# %%
#this code creates a list of selected few elements form a larger list
l = 0
final_list =[]
for item in range(0,740):
      c = txt_list[l]
      print(c)
      final_list.append(txt_list[l])
      l = l+10
print(final_list)
print(len(final_list))
# Out:
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/0.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/10.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/20.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/30.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/40.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/50.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/60.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/70.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/80.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/90.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/100.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/110.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/120.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/130.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/140.txt
# /home/saadi/mAP2/FULLSET_GT_PREDICTIONS_ /predicted/150.txt
# ...

# %%
# script copy files from one folder to another paths in list
import shutil, os
for f in final_list:
    shutil.copy(f, '/home/saadi/Desktop/test_xml _write/DATA FOR MAP/predicted_740')
